# %%
import requests
from requests.auth import HTTPDigestAuth
import os
import json
import time
import pandas as pd
import time
from pprint import pprint
from config import pet_finder_api_key, pet_finder_secret_key, gmaps_api_key
import geocoder
error_count = 0
petfinder_base_url = "https://api.petfinder.com/v2/"
# dictionary contains the address/latlong key-valule pairs addresses already geocoded
# Example:  geomapped_addresses = { "123 Main Street": "34,-120", "555 Elm Street Escondido, CA" : "33.21,-110.123" }
geomapped_addresses = {}

# %%
# https://stackoverflow.com/questions/16891340/remove-a-prefix-from-a-string
# removes unwanted characters (prefix) from the beginning of a string (s)
def remove_prefix(s, prefix):
    return s[len(prefix):] if s.startswith(prefix) else s

# %%
#create function for geo coding addresses
# simple library for geocoding ----  https://geocoder.readthedocs.io/ 

def geomapper(address):
    try:
        # remove leading "," from the address
        address = remove_prefix(address, ',')
        # check if address has already been geocoded, if so return that value from the geomapped_addresses dictionary
        if (address in geomapped_addresses):
            return geomapped_addresses[address]
        g = geocoder.google(address, key=gmaps_api_key)
        lat = g.json['lat']
        long = g.json['lng']
        latlong = f'{lat},{long}'
        # store the lat/long in the geomapped_addresses dictionary so we don't run the API on it again
        geomapped_addresses[address] = latlong
        
        if (len(geomapped_addresses) % 100 == 0):
            print(f"{len(geomapped_addresses)} addresses processed")
            file_name = "Resources/geomapped_addresses_temp.json"
            with open(file_name, 'w') as fp:
                json.dump(geomapped_addresses, fp, sort_keys=True, indent=4)
        return latlong
    except:
        #error_count += 1
        return None

# %%
#Create function called locateAddresses that adds latitude and longitude columns for geomapping
#Assumes df have column "address"
def locateAddresses(df):
    # Load any already geocoded addresses into geomapped_addresses dictionary
    file_name = "Resources/geomapped_addresses.json"
    if (os.path.isfile(file_name)):
        print("reading geomapped_addresses.json")
        with open(file_name, 'r') as fp:
            geomapped_addresses.update(json.load(fp))
        print(f"loaded {len(geomapped_addresses)} addresses")
        
    # create a copy of the passed in dataframe so we can manipulate it without getting reference errors
    df_temp = pd.DataFrame(df)
    df_temp["geo"] = 0
    df_temp["geo"]= df_temp.address.apply(lambda x: geomapper(x))
    #split geo column to assign values in latitude and longitude 
    df_temp[['Lat', 'Lng']] = df_temp.geo.str.split(',', expand = True)
    # no longer need the geo column...
    del df_temp['geo']
    
    # Save the geomapped_addresses dictionary to a file so we don't ever have to geomap addresses already done
    print(f"saving geomapped_addresses.json")
    with open(file_name, 'w') as fp:
        json.dump(geomapped_addresses, fp, sort_keys=True, indent=4)
        
    # return our local copy of the dataframe.  make sure you assign the return value of this function to a new df.
    return df_temp

# %%
def getAccessToken():
    url = f'{petfinder_base_url}oauth2/token'
    #print(url)
    #format post request body data
    #https://www.geeksforgeeks.org/get-post-requests-using-python/
    # data to be sent to api; data is the POST body
    data = {'grant_type':"client_credentials", 
            'client_id':pet_finder_api_key, 
            'client_secret':pet_finder_secret_key
           }
    #print(data)
    #how to add headers in python POSTS
    #https://stackoverflow.com/questions/8685790/adding-header-to-python-requests-module
    headers = {'Content-Type': 'application/x-www-form-urlencoded'}
    response = requests.post(url, data = data, headers=headers)
    #print(response)
    if(response.ok):
        jData = json.loads(response.content)
        #print(jData)
        return jData["access_token"]
    else:
        # If response code is not ok (200)
        return None

# %%
token = getAccessToken()
print(token)
# Out:
# eyJ0eXAiOiJKV1QiLCJhbGciOiJSUzI1NiIsImp0aSI6IjU0ZTJhY2I1Zjc4MmNlMjg0YjUzMzQxZmY1NDA3NWU1ODEzYjE1MTJlMmEwMTZhNDdjYWM3MDE4MGM0ZGJkZTIyOWFiNmExZTE2ZTYyMjYwIn0..g2EuuP6WgHeND_vESPSwqGfxlq2ZVMf1p3JSHBS9c0amytQLSoI1VpuuvWrox6WqPdDc4N7bNZLuSVEdeArTXzn0UP5WsRHyh0j9R8qaWisyzETjmkRUVDbQmZ-hyQ7kx1Xj70Y5k_2GZEcrNNDZ0KKlYEVXDho3DzbntggnStcvInvUu1a82_mCm8WrVQDapIk33Fa-JgNhnfZMZB2OnbgTXTCYcT5lgZB7WoUR_X2VdK8RE_OH8TiTQ890RbtlR_FKdF8lAhPJAw0lKxCztTmK2n-O0eoWOZm5D5YpQL5LN_m6vP6Fd_dyUTv41iehRnbeoAZlmSa7JalSe10L6w

# %%
#function to get total pages of results
def totalPages(animal_type,status,limit,location):
    url = f'{petfinder_base_url}animals?type={animal_type}&status={status}&limit={limit}&location={location}'
    print(url)
    #format for calls to animal api
    #https://api.petfinder.com/v2/animals?type=dog&page=2
    #headers: Authorization: Bearer eyJ0eXA...
    headers = {'Authorization': f'Bearer {token}'}
    response = requests.get(url, headers=headers )
    if(response.ok):
        jData = json.loads(response.content)
        return jData['pagination']['total_pages']
       
    else:
        print("Not found")
        return None

# %%
def fetchPet(animal_type,limit,status,page, location):
    url = f'{petfinder_base_url}animals?type={animal_type}&limit={limit}&status={status}&page={page}&location={location}'
    print(url)
    #format for calls to animal api
    #https://api.petfinder.com/v2/animals?type=dog&page=2
    #headers: Authorization: Bearer eyJ0eXA...
    headers = {'Authorization': f'Bearer {token}'}
    response = requests.get(url, headers=headers )
    if(response.ok):
        jData = json.loads(response.content)
        return jData

    else:
        print("Not found")
        return None

# %%
#To get total records
def getData(animal_type, limit, status, location):
    pets = []
    total_pages = totalPages(animal_type,status, limit,location)
    for  page in range(1,total_pages):
        petData = fetchPet(animal_type,limit,status,page,location)
        #print(petData)
        #append to a list from another list
        #https://stackabuse.com/append-vs-extend-in-python-lists/
        #pets.extend(petData["animals"])
        
        for row in petData["animals"]:
            
            pet_dict= {
            'pet_id': row['id'],
            'organization_id': row['organization_id'],
            'url': row['url'],
            'type': row['type'],
            'primary breed': row['breeds']['primary'],
            'secondary breed': row['breeds']['secondary'],
            'mixed breed': row['breeds']['mixed'],
            'age': row['age'],
            'gender': row['gender'],
            'size': row['size'],
            'photo1': '',
            'photo2': '',
            'photo3': '',
            'address1': '',
            'address2':'',
            'city': '',
            'state': '',
            'postcode': '',
            'email': '',
            'phone': ''
            }
            
            if len(row['photos']) > 0:
                pet_dict['photo1'] = row['photos'][0]['full']
            if len(row['photos']) > 1:
                pet_dict['photo2'] = row['photos'][1]['full']
            if len(row['photos']) > 2:
                pet_dict['photo3'] = row['photos'][2]['full']
                
                
                
            if 'contact' in row:
                contact = row['contact']
                
                if 'email' in contact:
                    pet_dict['email'] = row['contact']['email']
                if 'phone' in contact:
                    pet_dict['phone'] = row['contact']['phone']
                
                if 'address' in contact:
                    address = row['contact']['address']
                    if 'address1' in address:
                        pet_dict['address1'] = row['contact']['address']['address1']
                    if 'address2' in address:
                        pet_dict['address2'] = row['contact']['address']['address2']
                    if 'city' in address:
                        pet_dict['city'] = row['contact']['address']['city']
                    if 'state' in address:
                        pet_dict['state'] = row['contact']['address']['state']
                    if 'postcode' in address:
                        pet_dict['postcode'] = row['contact']['address']['postcode']
                
            pets.append(pet_dict)
            
    pets_city_df = pd.DataFrame(pets)
    pets_city_df = pets_city_df[["pet_id", "type", "primary breed", "secondary breed", "mixed breed", "size", "gender", "age", "photo1", "photo2", "organization_id", "phone", "address1", "address2", "city", "state", "postcode", "email"]]
  
    return pets_city_df

# %%
# load csv files if exist otherwise create by calling function getData
location = "San Diego, CA"
cats_city_df = None
cats_file = "Resources/cats_city.csv"
if (os.path.isfile(cats_file)):
    cats_city_df = pd.read_csv(cats_file)
    cats_city_df = cats_city_df.fillna("")
else:
    cats_city_df = getData(animal_type= "cat",limit = 100, status = "adoptable", location= location)
    cats_city_df.to_csv(cats_file,header=True, index=False)

# %%
dogs_city_df = None
location = "San Diego, CA"
dogs_file = "Resources/dogs_city.csv"
if (os.path.isfile(dogs_file)):
    dogs_city_df = pd.read_csv(dogs_file)
    dogs_city_df = dogs_city_df.fillna("")
else:
    dogs_city_df = getData(animal_type= "dog",limit = 100, status = "adoptable", location= location)
    dogs_city_df.to_csv(dogs_file,header=True, index=False)

# %%
dogs_city_df
# Out:
#         pet_id type                   primary breed  \
# 0     44338661  Dog                           Boxer
# 1     44338300  Dog              Labrador Retriever
# 2     44337830  Dog                          Poodle
# 3     44337831  Dog              Miniature Pinscher
# 4     44337828  Dog                Brittany Spaniel
# 5     44337359  Dog                     Rat Terrier
# 6     44337314  Dog                           Boxer
# 7     44337315  Dog                           Boxer
# 8     44337316  Dog                           Boxer
# 9     44337317  Dog                           Boxer
# 10    44337318  Dog                           Boxer
# 11    44337304  Dog              Labrador Retriever
# 12    44337305  Dog              Labrador Retriever
# 13    44337306  Dog              Labrador Retriever
# 14    44337307  Dog              Labrador Retriever
# 15    44337308  Dog              Labrador Retriever
# 16    44337309  Dog              Labrador Retriever
# 17    44337310  Dog              Labrador Retriever
# 18    44337311  Dog              Labrador Retriever
# 19    44337312  Dog              Labrador Retriever
# 20    44337313  Dog              Labrador Retriever
# 21    44336594  Dog          Parson Russell Terrier
# 22    44337053  Dog                       Chihuahua
# 23    44337056  Dog                        Shih Tzu
# 24    44337051  Dog             Rhodesian Ridgeback
# 25    44337052  Dog                        Shar-Pei
# 26    44336508  Dog                    Basset Hound
# 27    44336511  Dog                       Chihuahua
# 28    44336509  Dog                Pit Bull Terrier
# 29    44336507  Dog                Pit Bull Terrier
# ...        ...  ...                             ...
# 3570  26567806  Dog                         Maltese
# 3571  26517419  Dog  American Staffordshire Terrier
# 3572  26512673  Dog                Pit Bull Terrier
# 3573  26398253  Dog                Pit Bull Terrier
# 3574  26394878  Dog                       Chihuahua
# 3575  26081137  Dog                       Chihuahua
# 3576  26047754  Dog                           Jindo
# 3577  25492873  Dog               Australian Kelpie
# 3578  25290209  Dog                           Boxer
# 3579  25264391  Dog                         Terrier
# 3580  25183945  Dog                Pit Bull Terrier
# 3581  24152941  Dog              Labrador Retriever
# 3582  23920757  Dog  American Staffordshire Terrier
# 3583  23531670  Dog                         Terrier
# 3584  23531640  Dog          American Water Spaniel
# 3585  23159721  Dog                American Bulldog
# 3586  22952981  Dog                       Chihuahua
# 3587  22906363  Dog                  Border Terrier
# 3588  22905243  Dog                          Poodle
# 3589  22271540  Dog                     Rat Terrier
# 3590  22171080  Dog                      Rottweiler
# 3591  21990244  Dog                    Bull Terrier
# 3592  21238932  Dog                         Terrier
# 3593  20962015  Dog                       Dalmatian
# 3594  20559339  Dog                     Rat Terrier
# 3595  20559078  Dog                       Chihuahua
# 3596  19233763  Dog                        Shepherd
# 3597  19192641  Dog                      Pomeranian
# 3598  19183051  Dog                   Saint Bernard
# 3599  17760839  Dog          Parson Russell Terrier
#
#                      secondary breed  mixed breed         size  gender  \
# 0         German Shorthaired Pointer         True        Large    Male
# 1                                            True       Medium  Female
# 2                                           False        Small  Female
# 3                                           False        Small    Male
# 4                        Mixed Breed         True        Small    Male
# 5               Jack Russell Terrier         True        Small  Female
# 6                                            True        Large  Female
# 7                                            True        Large  Female
# 8                                            True        Large  Female
# 9                                            True        Large    Male
# 10                                           True        Large  Female
# 11                                           True        Large  Female
# 12                           Terrier         True       Medium  Female
# 13                           Terrier         True       Medium  Female
# 14                           Terrier         True       Medium  Female
# 15                           Terrier         True       Medium    Male
# 16                           Terrier         True       Medium  Female
# 17                           Terrier         True       Medium    Male
# 18                           Terrier         True       Medium    Male
# 19                           Terrier         True       Medium    Male
# 20                           Terrier         True       Medium  Female
# 21                 Yorkshire Terrier         True        Small  Female
# 22                                          False       Medium  Female
# 23                       Mixed Breed         True       Medium    Male
# 24                       Mixed Breed         True        Large    Male
# 25                  Pit Bull Terrier         True        Large    Male
# 26                       Mixed Breed         True       Medium    Male
# 27                                          False        Small    Male
# 28                                          False        Large  Female
# 29                       Mixed Breed         True        Large    Male
# ...                              ...          ...          ...     ...
# 3570                  Border Terrier         True        Small    Male
# 3571                Pit Bull Terrier         True        Large    Male
# 3572                         Mastiff         True       Medium    Male
# 3573                                        False       Medium    Male
# 3574                                         True        Small  Female
# 3575                                        False        Small    Male
# 3576              Labrador Retriever         True       Medium    Male
# 3577                                         True        Large    Male
# 3578  American Staffordshire Terrier         True       Medium  Female
# 3579                         Basenji         True       Medium  Female
# 3580                                         True       Medium  Female
# 3581                Pit Bull Terrier         True        Large  Female
# 3582                Pit Bull Terrier         True       Medium  Female
# 3583                         Spaniel         True        Small    Male
# 3584                         Terrier         True        Small    Male
# 3585                         Pointer         True        Large    Male
# 3576                                       San Diego    CA     92117
# 3577                                       RIVERSIDE    CA     92504
# 3578                                       San Diego    CA     92142
# 3579                                          Irvine    CA     92606
# 3580                          Rancho Santa Margarita    CA     92688
# 3581                          Rancho Santa Margarita    CA     92688
# 3582                                      Long Beach    CA     90803
# 3583                                       San Diego    CA     92142
# 3584                                       San Diego    CA     92142
# 3585                                       San Diego    CA     92117
# 3586                                          Colton    CA     92324
# 3587  www.dalrescuesocal.com           Newport Beach    CA     92660
# 3588  www.dalrescuesocal.com           Newport Beach    CA     92660
# 3589                                    Los Alamitos    CA     90720
# 3590                                       RIVERSIDE    CA     92504
# 3591                          Rancho Santa Margarita    CA     92688
# 3592                                         Ontario    CA     91761
# 3593                          Rancho Santa Margarita    CA     92688
# 3594                                       San Diego    CA     92142
# 3595                                       San Diego    CA     92142
# 3596                                 Mountain Center    CA     92561
# 3597                                       San Diego    CA     92117
# 3598                                      Bellflower    CA     90707
# 3599                                          Colton    CA     92324
#
#                                  email
# 0               poochmatch@hotmail.com
# 1        labradorsandfriends@yahoo.com
# 2              animalshelter@moval.org
# 3              animalshelter@moval.org
# 4              animalshelter@moval.org
# 5               poochmatch@hotmail.com
# 6              doginfo@labsandmore.org
# 7              doginfo@labsandmore.org
# 8              doginfo@labsandmore.org
# 9              doginfo@labsandmore.org
# 10             doginfo@labsandmore.org
# 11             doginfo@labsandmore.org
# 12             doginfo@labsandmore.org
# 13             doginfo@labsandmore.org
# 14             doginfo@labsandmore.org
# 15             doginfo@labsandmore.org
# 16             doginfo@labsandmore.org
# 17             doginfo@labsandmore.org
# 18             doginfo@labsandmore.org
# 19             doginfo@labsandmore.org
# 20             doginfo@labsandmore.org
# 21              poochmatch@hotmail.com
# 22        OCCRocpetinfo@occr.ocgov.com
# 23        OCCRocpetinfo@occr.ocgov.com
# 24        OCCRocpetinfo@occr.ocgov.com
# 25        OCCRocpetinfo@occr.ocgov.com
# 26                 rcpets@cityofrc.com
# 27                 rcpets@cityofrc.com
# 28                 rcpets@cityofrc.com
# 29                 rcpets@cityofrc.com
# ...                                ...
# 3570      cuteodyssey4ever@hotmail.com
# 3571      canineandkittycoop@gmail.com
# 3572         rescue@icaredogrescue.org
# 3573         rescue@icaredogrescue.org
# 3574           rescuenrehome@gmail.com
# 3575       pupsandpalsrescue@yahoo.com
# 3576            info@thebarkinglot.net
# 3577        topgunK9rescue@hotmail.com
# 3578         wizard188wizard@yahoo.com
# 3579         SweetHomeRescue@gmail.com
# 3580         rescue@icaredogrescue.org
# 3581         rescue@icaredogrescue.org
# 3582  treasuredtailsrescue@hotmail.com
# 3583         wizard188wizard@yahoo.com
# 3584         wizard188wizard@yahoo.com
# 3585            info@thebarkinglot.net
# 3586            beaglesrbest@yahoo.com
# 3587           dalrescue@sbcglobal.net
# 3588           dalrescue@sbcglobal.net
# 3589       pupsandpalsrescue@yahoo.com
# 3590        topgunK9rescue@hotmail.com
# 3591         rescue@icaredogrescue.org
# 3592        westendshelter@netzero.net
# 3593         rescue@icaredogrescue.org
# 0                                            True       Medium  Female
# 1                                            True       Medium    Male
# 2                                            True       Medium  Female
# 3                                            True       Medium    Male
# 4                                           False        Small    Male
# 5                                            True        Small  Female
# 6                Domestic Short Hair         True       Medium    Male
# 7                            Ragdoll         True        Large    Male
# 8                                           False        Large    Male
# 9                                           False       Medium  Female
# 10                                          False        Small  Female
# 11                                          False        Large    Male
# 12                                          False       Medium    Male
# 13                                          False        Small  Female
# 14                                          False       Medium  Female
# 15                                          False       Medium    Male
# 16                                          False       Medium  Female
# 17                                          False       Medium    Male
# 18                                          False       Medium  Female
# 19                                          False       Medium  Female
# 20                                          False       Medium  Female
# 21                                           True       Medium    Male
# 22                                           True       Medium    Male
# 23                            Calico         True       Medium  Female
# 24                                           True       Medium    Male
# 25                            Torbie         True       Medium  Female
# 26                                          False       Medium  Female
# 27               Domestic Short Hair         True       Medium  Female
# 28               Domestic Short Hair         True       Medium  Female
# 29                                          False        Small  Female
# ...                              ...          ...          ...     ...
# 3570                  Border Terrier         True        Small    Male
# 3571                Pit Bull Terrier         True        Large    Male
# 3572                         Mastiff         True       Medium    Male
# 3573                                        False       Medium    Male
# 3574                                         True        Small  Female
# 3575                                        False        Small    Male
# 3576              Labrador Retriever         True       Medium    Male
# 3577                                         True        Large    Male
# 3578  American Staffordshire Terrier         True       Medium  Female
# 3579                         Basenji         True       Medium  Female
# 3580                                         True       Medium  Female
# 3581                Pit Bull Terrier         True        Large  Female
# 3582                Pit Bull Terrier         True       Medium  Female
# 3583                         Spaniel         True        Small    Male
# 3584                         Terrier         True        Small    Male
# 3585                         Pointer         True        Large    Male
# 3586                       Dachshund         True       Medium    Male
# 3587                                         True        Small    Male
# 3588                   Cairn Terrier         True        Small  Female
# 3589                       Chihuahua         True        Small  Female
# 3590                                        False       Medium    Male
# 3591                Pit Bull Terrier         True        Large    Male
# 3592                                         True        Small    Male
# 3593  American Staffordshire Terrier         True        Large    Male
# 3594                                        False       Medium    Male
# 3595                                        False        Small  Female
# 3596                                         True       Medium    Male
# 3597                   Finnish Spitz         True       Medium    Male
# 3598                                        False  Extra Large  Female
# 3599                         Terrier         True       Medium  Female
#
#          age                                             photo1  \
# 0       Baby
# 1       Baby
# 2       Baby
# 3      Young
# 4      Young
# 5      Young
# 6      Adult
# 7      Young
# 8      Adult
# 9      Adult
# 10     Young
# 11     Young
# 12     Young
# 13     Young
# 14     Adult
# 15     Adult  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 16     Young  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 17      Baby  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 18     Adult  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 19      Baby  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 20     Young
# 21      Baby  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 22     Adult
# 23     Adult
# 24     Adult
# 25     Adult
# 26     Young  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 27     Adult  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 28     Adult  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 29     Adult  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# ...      ...                                                ...
# 3570  Senior  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 3571   Young  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 3572   Adult  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 3573   Adult  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 3574   Adult  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 3575   Adult  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 3576   Adult  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 3577   Adult  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 3578   Young  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 3579   Adult  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 3580   Adult  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 3581   Adult  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 3582   Adult  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 3583   Young  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 3584   Young  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 3585   Adult  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 3586   Young  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 3587   Young  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 3588   Young  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 3589   Adult  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 3590  Senior  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 3591   Adult  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 3592   Adult  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 3593   Adult  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 3594   Adult  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 3595   Young  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 3596   Adult  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 3597   Young  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 3598   Young  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 3599   Young  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
#
#                
# 3589            Los Alamitos    CA     90720       pupsandpalsrescue@yahoo.com
# 3590               RIVERSIDE    CA     92504        topgunK9rescue@hotmail.com
# 3591  Rancho Santa Margarita    CA     92688         rescue@icaredogrescue.org
# 3592                 Ontario    CA     91761        westendshelter@netzero.net
# 3593  Rancho Santa Margarita    CA     92688         rescue@icaredogrescue.org
# 3594               San Diego    CA     92142         wizard188wizard@yahoo.com
# 3595               San Diego    CA     92142         wizard188wizard@yahoo.com
# 3596         Mountain Center    CA     92561            kennel@living-free.org
# 3597               San Diego    CA     92117         wizard188wizard@yahoo.com
# 3598              Bellflower    CA     90707               pam@sunnysaints.org
# 3599                  Colton    CA     92324            beaglesrbest@yahoo.com
#
# [6300 rows x 18 columns]

# %%
#Add create combined address column and long and lat columns
#df['Name'] = df['First'].str.cat(df['Last'],sep=" ")
#dogs_df['address'] = dogs_df['address1'].str.cat(['city'],['state'],['postcode'],sep=" ")
cats_dogs_city_df['address'] = cats_dogs_city_df['address1'].map(str) + ',' + cats_dogs_city_df['city'].map(str) + ',' \
    + cats_dogs_city_df['state'].map(str)+ ' ' + cats_dogs_city_df['postcode'].map(str)
cats_dogs_city_df.head()
# Out:
#      pet_id type         primary breed secondary breed  mixed breed    size  \
# 0  44337850  Cat  Domestic Medium Hair                         True  Medium
# 1  44337851  Cat  Domestic Medium Hair                         True  Medium
# 2  44337852  Cat  Domestic Medium Hair                         True  Medium
# 3  44337849  Cat   Domestic Short Hair                         True  Medium
# 4  44337829  Cat   Domestic Short Hair                        False   Small
#
#    gender    age photo1 photo2 organization_id           phone  \
# 0  Female   Baby                         CA216  (951) 688-4340
# 1    Male   Baby                         CA216  (951) 688-4340
# 2  Female   Baby                         CA216  (951) 688-4340
# 3    Male  Young                         CA216  (951) 688-4340
# 4    Male  Young                         CA567  951.413.3790
#
#                  address1 address2           city state  postcode  \
# 0  6165 Industrial Avenue               Riverside    CA     92504
# 1  6165 Industrial Avenue               Riverside    CA     92504
# 2  6165 Industrial Avenue               Riverside    CA     92504
# 3  6165 Industrial Avenue               Riverside    CA     92504
# 4   14041 Elsworth Street           Moreno Valley    CA     92553
#
#                      email                                       address
# 0  adopt1@petsadoption.org     6165 Industrial Avenue,Riverside,CA 92504
# 1  adopt1@petsadoption.org     6165 Industrial Avenue,Riverside,CA 92504
# 2  adopt1@petsadoption.org     6165 Industrial Avenue,Riverside,CA 92504
# 3  adopt1@petsadoption.org     6165 Industrial Avenue,Riverside,CA 92504
# 4  animalshelter@moval.org  14041 Elsworth Street,Moreno Valley,CA 92553

# %%
print(len(cats_dogs_city_df["address"].unique()))
# Out:
# 295

# %%
#Add latitude and longitude columns for gmapping using the locateAddresses function
city_all_pets_file = "Resources/city_allpets.csv"
citypets_geo_df = None
if (os.path.isfile(city_all_pets_file)):
    citypets_geo_df = pd.read_csv(city_all_pets_file)
else:
    citypets_geo_df = locateAddresses(cats_dogs_city_df)
    citypets_geo_df.to_csv(city_all_pets_file,header=True, index=False)
citypets_geo_df.head()
# Out:
#      pet_id type         primary breed secondary breed  mixed breed    size  \
# 0  44337850  Cat  Domestic Medium Hair             NaN         True  Medium
# 1  44337851  Cat  Domestic Medium Hair             NaN         True  Medium
# 2  44337852  Cat  Domestic Medium Hair             NaN         True  Medium
# 3  44337849  Cat   Domestic Short Hair             NaN         True  Medium
# 4  44337829  Cat   Domestic Short Hair             NaN        False   Small
#
#    gender    age photo1 photo2  ...           phone                address1  \
# 0  Female   Baby    NaN    NaN  ...  (951) 688-4340  6165 Industrial Avenue
# 1    Male   Baby    NaN    NaN  ...  (951) 688-4340  6165 Industrial Avenue
# 2  Female   Baby    NaN    NaN  ...  (951) 688-4340  6165 Industrial Avenue
# 3    Male  Young    NaN    NaN  ...  (951) 688-4340  6165 Industrial Avenue
# 4    Male  Young    NaN    NaN  ...  951.413.3790     14041 Elsworth Street
#
#   address2           city state postcode                    email  \
# 0      NaN      Riverside    CA    92504  adopt1@petsadoption.org
# 1      NaN      Riverside    CA    92504  adopt1@petsadoption.org
# 2      NaN      Riverside    CA    92504  adopt1@petsadoption.org
# 3      NaN      Riverside    CA    92504  adopt1@petsadoption.org
# 4      NaN  Moreno Valley    CA    92553  animalshelter@moval.org
#
#                                         address        Lat         Lng
# 0     6165 Industrial Avenue,Riverside,CA 92504  33.966201 -117.437000
# 1     6165 Industrial Avenue,Riverside,CA 92504  33.966201 -117.437000
# 2     6165 Industrial Avenue,Riverside,CA 92504  33.966201 -117.437000
# 3     6165 Industrial Avenue,Riverside,CA 92504  33.966201 -117.437000
# 4  14041 Elsworth Street,Moreno Valley,CA 92553  33.915658 -117.270964
#
# [5 rows x 21 columns]

# %%
#TEST:  to return all results for a specific breed
breed = "Chihuahua"
state = "CA"
city = "San Diego"
citypets_geo_df =  citypets_geo_df.loc[(citypets_geo_df['primary breed']==breed)&(citypets_geo_df['city']==city ),:]
citypets_geo_df
# Out:
#         pet_id type primary breed secondary breed  mixed breed    size  \
# 2774  44332737  Dog     Chihuahua             NaN         True  Medium
# 2778  44332736  Dog     Chihuahua             NaN         True  Medium
# 2982  44318051  Dog     Chihuahua         Terrier         True  Medium
# 3055  44309924  Dog     Chihuahua             NaN         True  Medium
# 3056  44309921  Dog     Chihuahua             NaN         True  Medium
# 3057  44309922  Dog     Chihuahua             NaN         True  Medium
# 3079  44306389  Dog     Chihuahua             NaN         True   Small
# 3151  44299589  Dog     Chihuahua             NaN         True  Medium
# 3152  44299588  Dog     Chihuahua             NaN         True  Medium
# 3216  44290229  Dog     Chihuahua       Dachshund         True   Small
# 3517  44256816  Dog     Chihuahua             NaN        False   Small
# 3642  44237394  Dog     Chihuahua             NaN         True   Small
# 3713  44226796  Dog     Chihuahua             NaN         True   Small
# 3714  44226795  Dog     Chihuahua             NaN         True   Small
# 3820  44202528  Dog     Chihuahua             NaN         True  Medium
# 3849  44200516  Dog     Chihuahua             NaN        False   Small
# 3951  44178082  Dog     Chihuahua             NaN         True   Small
# 4031  44158479  Dog     Chihuahua          Poodle         True   Small
